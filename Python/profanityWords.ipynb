# %%
pip install profanity
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for profanity: filename=profanity-1.1-py3-none-any.whl size=4225 sha256=4a970797915ceb8a6262d78ed859af7ecdaad63046205175b02056a7781dfeb4
#   Stored in directory: /root/.cache/pip/wheels/2e/05/26/847aedfe1aa25a89f3ed55d4326de446f2b1a7851223c5ca7a
# Successfully built profanity
# ...

# %%
from profanity import profanity

profanity.contains_profanity("You smell like shit.")
profanity.censor("You smell like shit.")

print(profanity.words)
# Out:
# ['anal', 'anus', 'ballsack', 'blowjob', 'blow job', 'boner', 'clitoris', 'cock', 'cunt', 'dick', 'dildo', 'dyke', 'fag', 'fuck', 'jizz', 'labia', 'muff', 'nigger', 'nigga', 'penis', 'piss', 'pussy', 'scrotum', 'sex', 'shit', 'slut', 'smegma', 'spunk', 'twat', 'vagina', 'wank', 'whore']
